# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import re

# %%
url = 'https://en.wikipedia.org/wiki/Firearm_death_rates_in_the_United_States_by_state'
web_data = requests.get(url).text
soup = BeautifulSoup(web_data, 'html.parser')

# %%
table = 'wikitable sortable static-row-numbers plainrowheaders srn-white-background'
if soup:
    result = soup.find_all('table', class_=table)

# %%
print(f'{result[0]}')
# Out:
# <table border="1" class="wikitable sortable static-row-numbers plainrowheaders srn-white-background" style="text-align:right;">
# <caption>2019 firearm death rates, firearm death counts, and total murder counts (regardless of method) by state.<sup class="reference" id="cite_ref-NCHS-map_6-1"><a href="#cite_note-NCHS-map-6">[6]</a></sup>
# </caption>
# <tbody><tr>
# <th>State</th>
# <th>Abbreviation</th>
# <th>Rate per 100,000 people</th>
# <th>Gun Deaths</th>
# <th>Murders
# </th></tr>
# <tr>
# ...

# %%
my_table = result[0]
# my_table

# %%
for td in my_table.find_all('td'):
    text = re.search("^</td><td>$", td)
    val1 = re.search()
